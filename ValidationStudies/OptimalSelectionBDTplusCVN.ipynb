# %%
import numpy as np
from array import *
import matplotlib.pyplot as plt
import math
import time
# Out:
# /home/leoperes/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
#Read CosSun Score for each lorentz factor and atmospheric neutrinos

CosSun_b1p1_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m05_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m05_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m05_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_b1p1_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m10_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m10_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m10_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_b1p1_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m20_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m20_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m20_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_b1p1_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m40_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m40_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_m40_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSun_Atm_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

# %%
#Read CosSun Score for each lorentz factor and atmospheric neutrinos after cuts

CosSun_Signal_b1p1_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m05_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m05_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m05_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Signal_b1p1_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m10_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m10_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m10_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Signal_b1p1_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m20_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m20_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m20_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Signal_b1p1_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m40_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m40_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunSignalAfterCuts_m40_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)


CosSun_Atm_b1p1_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m05_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m05_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m05 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m05_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm_b1p1_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m10_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m10_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m10 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m10_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm_b1p1_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m20_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m20_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m20 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m20_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm_b1p1_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m40_b1p1.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m40_b1p5.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m40 = np.loadtxt('../Optimization/NuclearModelsOptSelectionApplication/hA_BR/CosSunAtmAfterCuts_m40_b10.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=12)

plt.figure(dpi=150)
plt.xlabel(r'$\cos (\theta_{Sun})$', fontsize = 18)
plt.yscale('log')
plt.ylim([50,1e4])
h1, x1, _ = plt.hist(CosSun_Atm_b1p1_m10, bins= 30, density=False, label=r'Atm-$\nu$ w/ CVN+BDT Selection', histtype='step',lw =1, color = 'blue', ls='--')
h2, x2, _ = plt.hist(CosSun_Signal_b1p1_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$ w/ CVN+BDT Selection', histtype='step', color='darkorange',lw =1, ls='--')
h3, x3, _ = plt.hist(CosSun_Atm, bins= 30, density=False, label=r'Atm-$\nu$', histtype='step', lw =1, color = 'blue', ls= '-')
h4, x4, _ = plt.hist(CosSun_b1p1_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$', histtype='step', lw =1,color = 'darkorange')
#plt.xlabel(r'$\cos(\theta_{\Sun})$')
plt.ylabel('Number of Events Reconstructed')
plt.legend(title = r'$\gamma = 1.1,$ hA+BR',loc='lower center',ncol=2, fontsize=10)
plt.savefig('b1p1_cvnbdt_selection'+str(time.strftime("%Y%m%d"))+'.pdf', format='pdf', dpi=600)
plt.show()

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=12)

plt.figure(dpi=150)
plt.xlabel(r'$\cos (\theta_{Sun})$', fontsize = 18)
plt.yscale('log')
plt.ylim([50,1e4])
h1, x1, _ = plt.hist(CosSun_Atm_b1p5_m10, bins= 30, density=False, label=r'Atm-$\nu$ w/ CVN+BDT Selection', histtype='step',lw =1, color = 'blue', ls='--')
h2, x2, _ = plt.hist(CosSun_Signal_b1p5_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$ w/ CVN+BDT Selection', histtype='step', color='darkorange',lw =1, ls='--')
h3, x3, _ = plt.hist(CosSun_Atm, bins= 30, density=False, label=r'Atm-$\nu$', histtype='step', lw =1, color = 'blue', ls= '-')
h4, x4, _ = plt.hist(CosSun_b1p5_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$', histtype='step', lw =1,color = 'darkorange')
#plt.xlabel(r'$\cos(\theta_{\Sun})$')
plt.ylabel('Number of Events Reconstructed')
plt.legend(title = r'$\gamma = 1.5,$ hA+BR',loc='lower center',ncol=2, fontsize=10)
plt.savefig('b1p5_cvnbdt_selection'+str(time.strftime("%Y%m%d"))+'.pdf', format='pdf', dpi=600)
plt.show()

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=12)
#bestCutRight=0.872
plt.figure(dpi=150)
plt.xlabel(r'$\cos (\theta_{Sun})$', fontsize = 18)
plt.yscale('log')
plt.ylim([50,1e4])
h1, x1, _ = plt.hist(CosSun_Atm_b10_m10, bins= 30, density=False, label=r'Atm-$\nu$ w/ CVN+BDT Selection', histtype='step',lw =1, color = 'blue', ls='--')
h2, x2, _ = plt.hist(CosSun_Signal_b10_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$ w/ CVN+BDT Selection', histtype='step', color='darkorange',lw =1, ls='--')
h3, x3, _ = plt.hist(CosSun_Atm, bins= 30, density=False, label=r'Atm-$\nu$', histtype='step', lw =1, color = 'blue', ls= '-')
h4, x4, _ = plt.hist(CosSun_b10_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$', histtype='step', lw =1,color = 'darkorange')
#plt.xlabel(r'$\cos(\theta_{\Sun})$')
h = max(h1.max(),h2.max(),h3.max(), h4.max())
#plt.vlines(bestCutRight, 0, 1e6, colors='darkolivegreen', linestyles='solid',lw=2)
#plt.plot(bestCutRight+0.06, h.max()*2, marker=r'$\rightarrow$', markersize=20,markerfacecolor='darkolivegreen',markeredgecolor="darkolivegreen")
plt.ylabel('Number of Events Reconstructed')
plt.legend(title = r'$\gamma = 10,$ hA+BR',loc='lower center',ncol=2, fontsize=10)
plt.savefig('b10_cvnbdt_selection'+str(time.strftime("%Y%m%d"))+'.pdf', format='pdf', dpi=600)
plt.show()

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=12)
#bestCutRight=0.872
plt.figure(dpi=150)
plt.xlabel(r'$\cos (\theta)$', fontsize = 18)
plt.yscale('log')
plt.ylim([50,5e4])
plt.xlim([-1,1])
h1, x1, _ = plt.hist(CosSun_b1p1_m10, bins= 30, density=False, label=r'$\gamma = 1.1$', histtype='step',lw =2, ls='-')
h2, x2, _ = plt.hist(CosSun_b1p5_m10, bins= 30, density=False, label=r'$\gamma = 1.5$', histtype='step', lw =2, ls='-')
h3, x3, _ = plt.hist(CosSun_b10_m10, bins= 30, density=False, label=r'$\gamma = 10$', histtype='step', lw =2, ls= '-')
h4, x4, _ = plt.hist(CosSun_Atm, bins= 30, density=False, label=r'Atm-$\nu$', histtype='step', lw =2, color = 'blue', ls= '-')
#plt.xlabel(r'$\cos(\theta_{\Sun})$')
h = max(h1.max(),h2.max(),h3.max(),h4.max())
#plt.vlines(bestCutRight, 0, 1e6, colors='darkolivegreen', linestyles='solid',lw=2)
#plt.plot(bestCutRight+0.06, h.max()*2, marker=r'$\rightarrow$', markersize=20,markerfacecolor='darkolivegreen',markeredgecolor="darkolivegreen")
plt.ylabel('Number of Events Reconstructed')
plt.legend(title = r'\textbf{DUNE IN PROGRESS}\\BDM: $m_\chi=10 \textrm{ GeV}$, hA+BR',loc='upper left', fontsize=10, ncols=2)
plt.savefig('all_cos_'+str(time.strftime("%Y%m%d"))+'.pdf', format='pdf', dpi=600)
plt.show()

# %%
print(CosSun_b1p1_m10.size,
CosSun_b1p5_m10.size,
CosSun_b10_m10.size,
CosSun_Atm.size)
# Out:
# 9449 72024 90336 220572
