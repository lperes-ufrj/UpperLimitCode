# %% [markdown]
# #### Atmospheric Neutrinos Uncertainties assumed in the Boosted Dark Matter Analysis.

# %%
import numpy as np 
import matplotlib.pyplot as plt
import math
import ROOT
# Out:
# /home/leoperes/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# Let's load Atmospheric Neutrino Samples:

# %%
LIST_NUCLEARMODELS = ['hA_BR','hA_LFG', 'hA_ESF', 'hN_BR', 'hN_LFG', 'hN_ESF']

def ReadNuclearModelSamples():

        fAtm_00a = ROOT.TFile.Open('/home/leoperes/ntuples_grid_newVertex/00a_newVertex/atm_hA_BR.root')
        fAtm_01a = ROOT.TFile.Open('/home/leoperes/ntuples_grid_newVertex/01a_newVertex/atm_hA_LFG.root')
        fAtm_02a = ROOT.TFile.Open('/home/leoperes/ntuples_grid_newVertex/02a_newVertex/atm_hA_ESF.root')
        fAtm_00b = ROOT.TFile.Open('/home/leoperes/ntuples_grid_newVertex/00b_newVertex/atm_hN_BR.root')
        fAtm_01b = ROOT.TFile.Open('/home/leoperes/ntuples_grid_newVertex/01b_newVertex/atm_hN_LFG.root')
        fAtm_02b = ROOT.TFile.Open('/home/leoperes/ntuples_grid_newVertex/02b_newVertex/atm_hN_ESF.root')
        samples = [fAtm_00a, fAtm_01a, fAtm_02a, fAtm_00b, fAtm_01b, fAtm_02b]
        return samples

def GetNpArraysFromTrees2(tree, branch_name):
    estimate = 3e8 #amount of numbers getting from branch
    tree.SetEstimate(int(estimate))
    result_hist = tree.Draw(branch_name, "", "goff")
    result = np.asarray(np.frombuffer(tree.GetV1(), count=result_hist))
    result = result.copy()
    return result

infiles_list = ReadNuclearModelSamples()
intrees_reco = [lambda arg=infile: arg.Get("ana/Atm") for infile in infiles_list]
reco_entries = [lambda arg=intree: arg.Get("ana/Atm").GetEntries() for intree in infiles_list]

# %% [markdown]
# ##### Sources of systematic uncertainties:
# > - Overall Neutrino Flux Uncertainty
# > - Geometrical Effect makes Atmospheric Neutrino Flux not exactly isotropic.
# > - Signal contamination in the side band region.
#
# First topic is the calculation of the Overall neutrino flux uncertainty. Using the sideband from the angular cuts to constraint background uncertainty.
# Thus, we take every angular distribution from the 6 nuclear models. Apply the angular selection cuts for each BDM sample, and then, take the percentage refer to the square root of the number expected events in the sideband  ($\sqrt{N_{bkg}}$).

# %% [markdown]
# #### Let's plot the angular distribution of atmospheric neutrinos w.r.t Sun's direction for each nuclear model.

# %%
# Create a 3x2 grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(10, 8))

# Flatten the axes array for easy iteration
axes = axes.flatten()

hist_numodel = []
for SAMPLE_INDEX in range(0,6):
    ### Atmospheric neutrinos Angular Reconstruction w.r.t Sun

    TotalMomRecoRangeUnitVect_Reco = GetNpArraysFromTrees2(intrees_reco[SAMPLE_INDEX]()," TotalMomRecoRangeUnitVect")
    nSimulatedEvtsReco_atm = reco_entries[SAMPLE_INDEX]()
    Reco_mom_Nu = np.reshape(TotalMomRecoRangeUnitVect_Reco, (nSimulatedEvtsReco_atm,3))
    Sun_Positions = np.loadtxt('../Optimization/background_sun_pos.dat', delimiter='\t', usecols=(0,1,2))

    hist_cos_reco = []
    for index, atmevt in enumerate(Reco_mom_Nu):
        indices = np.random.randint(0, len(Sun_Positions), size=1)
        # Use the sampled indices to select elements from the array
        sample_sunpos = Sun_Positions[indices]
        for sunpos in sample_sunpos:
            hist_cos_reco.append(np.sum(atmevt*sunpos))

    hist_numodel.append(hist_cos_reco)

# Plot each graph
for i, ax in enumerate(axes):
    ax.hist(hist_numodel[i], bins = 30,histtype = 'step', label=r'Atmos $\nu$: '+LIST_NUCLEARMODELS[i], lw =2)
    ax.legend(loc = 'lower center')

# Add a single unique x label at the bottom
fig.supxlabel(r'$cos(\theta_{Sun, Reco})$',fontsize = 17)

# Add a single unique y label on the left
fig.supylabel('Number of Events')

# Adjust layout for better spacing
plt.tight_layout()

plt.savefig('AngularStudiesPlots/AtmosphericsNuDistributionWRTSunSeparated.pdf', format='pdf', dpi=600)
# Show the plots
plt.show()

# %%
plt.figure(dpi=100)
plt.hist([f for f in hist_numodel], bins = 100, histtype = 'step', label= [l for l in LIST_NUCLEARMODELS], density=1)
#plt.title(f'index number evt: {index}')
plt.ylabel('Arb. Units')
plt.xlabel(r'$cos(\theta_{Sun, Reco})$',fontsize = 17)
plt.legend(loc = 'lower center', ncols =2)
plt.savefig('AngularStudiesPlots/AtmosphericsNuDistributionWRTSun.pdf', format='pdf', dpi=600)
plt.show()

# %% [markdown]
# #### Estimating the uncertainty from the sideband:

# %%
main_folder = '../Optimization/NuclearModelsOptSelectionApplication/'
#Atmospheric Neutrino Angular Distributions 
CosSun_Atm_list = ['hA_BR/CosSun_Atm_00a.txt','hA_LFG/CosSun_Atm_01a.txt', 'hA_ESF/CosSun_Atm_02a.txt', 'hN_BR/CosSun_Atm_00b.txt','hN_LFG/CosSun_Atm_01b.txt', 'hN_ESF/CosSun_Atm_02b.txt']
OptimalAngCuts = np.loadtxt('../Optimization/Optimization_DefaultNuclearModel/Eff_Bkg_index_00a.txt', usecols=(1,2,4), skiprows=1)
#Sample labels
labelsamples= ["b1p1_m05","b1p1_m10","b1p1_m20","b1p1_m40","b1p5_m05","b1p5_m10","b1p5_m20","b1p5_m40","b10_m05","b10_m10","b10_m20","b10_m40"]
ExpectedNumber10kty = [4*10*2495.98, 4*10*2586.47, 4*10*2401.88]
print('========== SYSTEMATIC UNCERTAINTY PER NUCLEAR MODEL BY THE SIDE BAND CONSTRAINT ===========')
ExpectedBkgList = ExpectedNumber10kty

LargerUnc = 1e-3
# Out:
# ========== SYSTEMATIC UNCERTAINTY PER NUCLEAR MODEL BY THE SIDE BAND CONSTRAINT ===========

# %%
for index in range(0, len(labelsamples)):
    for i in range(0,len(CosSun_Atm_list)):
        
        ExpectedBkg = 0
        if i % 3 == 0:
            ExpectedBkg = ExpectedBkgList[0]
        if i % 3 == 1:
            ExpectedBkg = ExpectedBkgList[1]
        if i % 3 == 2:
            ExpectedBkg = ExpectedBkgList[2]

        print('====================================================\n')
        print('Atmospheric Nuclear Model: '+ CosSun_Atm_list[i])
        AtmosphericSample = np.loadtxt(main_folder+CosSun_Atm_list[i])
        print('Sample: '+labelsamples[index]+'\n')
        print(f'Total Expected Number of Neutrinos Interactions: {round(ExpectedBkg)}\n')
        print(f'Number of Atmospheric Neutrinos Events Reconstructed: {AtmosphericSample.size}')
        print(f'Optimal Cosine Cuts => cos(theta_Sun) < {OptimalAngCuts[index][0]} and cos(theta_Sun) > {OptimalAngCuts[index][1]}. \n')
        EventsWithinOptAngCuts = AtmosphericSample[AtmosphericSample < OptimalAngCuts[index][0]].size +  AtmosphericSample[AtmosphericSample > OptimalAngCuts[index][1]].size
        print(f'Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: {EventsWithinOptAngCuts} \n')
        ExpectedBkgWithinOptAngCuts = ExpectedBkg*(EventsWithinOptAngCuts/AtmosphericSample.size)
        print(f'Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: {round(ExpectedBkgWithinOptAngCuts)} \n')
        print(f'Square root: {round(math.sqrt(ExpectedBkgWithinOptAngCuts))}')
        print(f'Uncertainty: {round(math.sqrt(ExpectedBkgWithinOptAngCuts)/ExpectedBkgWithinOptAngCuts,3)*100 }%')

        if (round(math.sqrt(ExpectedBkgWithinOptAngCuts)/ExpectedBkgWithinOptAngCuts,3)*100 >  LargerUnc):
            LargerUnc = round(math.sqrt(ExpectedBkgWithinOptAngCuts)/ExpectedBkgWithinOptAngCuts,3)*100
print(f'The Larger uncertainty found combining all nuclear models in all selection cuts is: {LargerUnc} %')
# Out:
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 19025
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8611
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 123449
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8992
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 90843
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8412
#
# Square root: 92
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97252
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8643
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97707
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9008
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 96477
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8340
#
# Square root: 91
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 19025
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8611
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 123449
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8992
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 90843
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8412
#
# Square root: 92
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97252
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8643
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97707
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9008
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 96477
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8340
#
# Square root: 91
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 11937
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5403
#
# Square root: 74
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 77336
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5633
#
# Square root: 75
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 56943
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5273
#
# Square root: 73
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 60883
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5411
#
# Square root: 74
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 61151
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5638
#
# Square root: 75
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 60560
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5235
#
# Square root: 72
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 13212
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5980
#
# Square root: 77
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 85333
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 6216
#
# Square root: 79
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 62923
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5827
#
# Square root: 76
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 67317
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5983
#
# Square root: 77
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 67588
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 6231
#
# Square root: 79
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 66805
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5775
#
# Square root: 76
# Uncertainty: 1.3%
# The Larger uncertainty found combining all nuclear models in all selection cuts is: 1.4000000000000001 %

# %%
main_folder = '../Optimization/NuclearModelsOptSelectionApplication/'
#Atmospheric Neutrino Angular Distributions 
CosSun_Atm_list = ['hA_BR/CosSun_Atm_00a.txt','hA_LFG/CosSun_Atm_01a.txt', 'hA_ESF/CosSun_Atm_02a.txt', 'hN_BR/CosSun_Atm_00b.txt','hN_LFG/CosSun_Atm_01b.txt', 'hN_ESF/CosSun_Atm_02b.txt']
OptimalAngCuts = np.loadtxt('../Optimization/Optimization_DefaultNuclearModel/Eff_Bkg_index_00a.txt', usecols=(1,2,4), skiprows=1)
#Sample labels
labelsamples= ["b1p1_m05","b1p1_m10","b1p1_m20","b1p1_m40","b1p5_m05","b1p5_m10","b1p5_m20","b1p5_m40","b10_m05","b10_m10","b10_m20","b10_m40"]
ExpectedBkg = 4*10*2495.98
print('========== SYSTEMATIC UNCERTAINTY PER NUCLEAR MODEL BY THE SIDE BAND CONSTRAINT ===========')

LargerUnc = 1e-3
# Out:
# ========== SYSTEMATIC UNCERTAINTY PER NUCLEAR MODEL BY THE SIDE BAND CONSTRAINT ===========

# %%
for index in range(0, len(labelsamples)):
    for i in range(0,len(CosSun_Atm_list)):

        print('====================================================\n')
        print('Atmospheric Nuclear Model: '+ CosSun_Atm_list[i])
        AtmosphericSample = np.loadtxt(main_folder+CosSun_Atm_list[i])
        print('Sample: '+labelsamples[index]+'\n')
        print(f'Total Expected Number of Neutrinos Interactions: {round(ExpectedBkg)}\n')
        print(f'Number of Atmospheric Neutrinos Events Reconstructed: {AtmosphericSample.size}')
        print(f'Optimal Cosine Cuts => cos(theta_Sun) < {OptimalAngCuts[index][0]} and cos(theta_Sun) > {OptimalAngCuts[index][1]}. \n')
        EventsWithinOptAngCuts = AtmosphericSample[AtmosphericSample < OptimalAngCuts[index][0]].size +  AtmosphericSample[AtmosphericSample > OptimalAngCuts[index][1]].size
        print(f'Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: {EventsWithinOptAngCuts} \n')
        ExpectedBkgOutOptAngCuts = ExpectedBkg*(1-(EventsWithinOptAngCuts/AtmosphericSample.size))
        print(f'Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: {round(ExpectedBkgOutOptAngCuts,1)} \n')
        print(f'Square root: {round(math.sqrt(ExpectedBkgOutOptAngCuts))}')
        print(f'sqrt(N)/N: {math.sqrt(ExpectedBkgOutOptAngCuts)/ExpectedBkgOutOptAngCuts}')
        print(f'Uncertainty: {round(math.sqrt(ExpectedBkgOutOptAngCuts)/ExpectedBkgOutOptAngCuts,3)*100 }%')

        if (round(math.sqrt(ExpectedBkgOutOptAngCuts)/ExpectedBkgOutOptAngCuts,3)*100 >  LargerUnc):
            LargerUnc = round(math.sqrt(ExpectedBkgOutOptAngCuts)/ExpectedBkgOutOptAngCuts,3)*100
print(f'The Larger uncertainty found combining all nuclear models in all selection cuts is: {LargerUnc} %')
# Out:
# ========== SYSTEMATIC UNCERTAINTY PER NUCLEAR MODEL BY THE SIDE BAND CONSTRAINT ===========
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89587.9
#
# Square root: 299
# sqrt(N)/N: 0.003340990971399476
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89495.6
#
# Square root: 299
# sqrt(N)/N: 0.0033427144233183666
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89445.1
#
# Square root: 299
# sqrt(N)/N: 0.0033436561397494446
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89491.2
#
# Square root: 299
# sqrt(N)/N: 0.0033427960231270167
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89478.8
#
# Square root: 299
# sqrt(N)/N: 0.0033430280892647927
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89457.6
#
# Square root: 299
# sqrt(N)/N: 0.0033434235855013318
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89587.9
#
# Square root: 299
# sqrt(N)/N: 0.003340990971399476
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89495.6
#
# Square root: 299
# sqrt(N)/N: 0.0033427144233183666
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89445.1
#
# Square root: 299
# sqrt(N)/N: 0.0033436561397494446
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89491.2
#
# Square root: 299
# sqrt(N)/N: 0.0033427960231270167
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89478.8
#
# Square root: 299
# sqrt(N)/N: 0.0033430280892647927
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89457.6
#
# Square root: 299
# sqrt(N)/N: 0.0033434235855013318
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89587.9
#
# Square root: 299
# sqrt(N)/N: 0.003340990971399476
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89495.6
#
# Square root: 299
# sqrt(N)/N: 0.0033427144233183666
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89445.1
#
# Square root: 299
# sqrt(N)/N: 0.0033436561397494446
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89491.2
#
# Square root: 299
# sqrt(N)/N: 0.0033427960231270167
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89478.8
#
# Square root: 299
# sqrt(N)/N: 0.0033430280892647927
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89457.6
#
# Square root: 299
# sqrt(N)/N: 0.0033434235855013318
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89587.9
#
# Square root: 299
# sqrt(N)/N: 0.003340990971399476
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89495.6
#
# Square root: 299
# sqrt(N)/N: 0.0033427144233183666
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89445.1
#
# Square root: 299
# sqrt(N)/N: 0.0033436561397494446
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89491.2
#
# Square root: 299
# sqrt(N)/N: 0.0033427960231270167
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89478.8
#
# Square root: 299
# sqrt(N)/N: 0.0033430280892647927
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 89457.6
#
# Square root: 299
# sqrt(N)/N: 0.0033434235855013318
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92132.2
#
# Square root: 304
# sqrt(N)/N: 0.003294536646182477
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92086.1
#
# Square root: 303
# sqrt(N)/N: 0.0032953612848647326
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92026.0
#
# Square root: 303
# sqrt(N)/N: 0.0032964369833445996
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92116.8
#
# Square root: 304
# sqrt(N)/N: 0.003294811514861521
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92073.3
#
# Square root: 303
# sqrt(N)/N: 0.0032955902575514777
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92094.2
#
# Square root: 303
# sqrt(N)/N: 0.0032952161280923264
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92132.2
#
# Square root: 304
# sqrt(N)/N: 0.003294536646182477
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92086.1
#
# Square root: 303
# sqrt(N)/N: 0.0032953612848647326
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92026.0
#
# Square root: 303
# sqrt(N)/N: 0.0032964369833445996
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92116.8
#
# Square root: 304
# sqrt(N)/N: 0.003294811514861521
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92073.3
#
# Square root: 303
# sqrt(N)/N: 0.0032955902575514777
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92094.2
#
# Square root: 303
# sqrt(N)/N: 0.0032952161280923264
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92132.2
#
# Square root: 304
# sqrt(N)/N: 0.003294536646182477
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92086.1
#
# Square root: 303
# sqrt(N)/N: 0.0032953612848647326
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92026.0
#
# Square root: 303
# sqrt(N)/N: 0.0032964369833445996
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92116.8
#
# Square root: 304
# sqrt(N)/N: 0.003294811514861521
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92073.3
#
# Square root: 303
# sqrt(N)/N: 0.0032955902575514777
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92094.2
#
# Square root: 303
# sqrt(N)/N: 0.0032952161280923264
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92132.2
#
# Square root: 304
# sqrt(N)/N: 0.003294536646182477
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92086.1
#
# Square root: 303
# sqrt(N)/N: 0.0032953612848647326
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92026.0
#
# Square root: 303
# sqrt(N)/N: 0.0032964369833445996
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92116.8
#
# Square root: 304
# sqrt(N)/N: 0.003294811514861521
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92073.3
#
# Square root: 303
# sqrt(N)/N: 0.0032955902575514777
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 92094.2
#
# Square root: 303
# sqrt(N)/N: 0.0032952161280923264
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 19025
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91227.8
#
# Square root: 302
# sqrt(N)/N: 0.003310826192825477
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 123449
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91161.3
#
# Square root: 302
# sqrt(N)/N: 0.003312033039267048
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 90843
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91097.6
#
# Square root: 302
# sqrt(N)/N: 0.003313191959597809
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97252
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91196.3
#
# Square root: 302
# sqrt(N)/N: 0.0033113985977893203
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97707
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91146.6
#
# Square root: 302
# sqrt(N)/N: 0.00331230069805928
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 96477
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91172.4
#
# Square root: 302
# sqrt(N)/N: 0.003311831926550665
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 19025
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91227.8
#
# Square root: 302
# sqrt(N)/N: 0.003310826192825477
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 123449
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91161.3
#
# Square root: 302
# sqrt(N)/N: 0.003312033039267048
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 90843
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91097.6
#
# Square root: 302
# sqrt(N)/N: 0.003313191959597809
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97252
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91196.3
#
# Square root: 302
# sqrt(N)/N: 0.0033113985977893203
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97707
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91146.6
#
# Square root: 302
# sqrt(N)/N: 0.00331230069805928
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 96477
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 91172.4
#
# Square root: 302
# sqrt(N)/N: 0.003311831926550665
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 11937
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 94436.1
#
# Square root: 307
# sqrt(N)/N: 0.003254100824638412
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 77336
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 94402.9
#
# Square root: 307
# sqrt(N)/N: 0.003254673554372385
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 56943
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 94359.7
#
# Square root: 307
# sqrt(N)/N: 0.003255417785344771
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 60883
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 94428.4
#
# Square root: 307
# sqrt(N)/N: 0.003254232649762458
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 61151
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 94398.8
#
# Square root: 307
# sqrt(N)/N: 0.0032547427258678703
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 60560
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 94398.9
#
# Square root: 307
# sqrt(N)/N: 0.0032547412246970186
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 13212
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 93859.0
#
# Square root: 306
# sqrt(N)/N: 0.0032640897337883248
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 85333
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 93840.7
#
# Square root: 306
# sqrt(N)/N: 0.003264407515525276
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 62923
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 93784.3
#
# Square root: 306
# sqrt(N)/N: 0.0032653898291975895
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 67317
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 93856.6
#
# Square root: 306
# sqrt(N)/N: 0.0032641304145959015
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 67588
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 93826.2
#
# Square root: 306
# sqrt(N)/N: 0.0032646603782769757
# Uncertainty: 0.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 66805
#
# Number of Expected Atmospheric Neutrino Events Reconstructed sideband region: 93837.9
#
# Square root: 306
# sqrt(N)/N: 0.0032644558817781
# Uncertainty: 0.3%
# The Larger uncertainty found combining all nuclear models in all selection cuts is: 0.3 %

# %% [markdown]
# ## The Larger uncertainty found combining all nuclear models in all selection cuts is: 0.3 %.

# %% [markdown]
# ### Step 2: Estimate the uncertainty given by the almost isotropic angular distribution of atmospheric neutrinos w.r.t Sun's direction.

# %%
for numodel in hist_numodel:
    hist, bin_edges = np.histogram(numodel, bins = 20)
    print(np.max(hist)/np.min(hist))
# Out:
# 1.066522083094634
# 1.0664137449851736
# 1.0909637708763558
# 1.0734385977887069
# 1.0722792080297998
# 1.0766305664808844

# %% [markdown]
# ### Step 3: Uncertainty from BDM signal reconstruction in the sideband.
# We need to estimate conservatively the number of signal events in the sideband region. There is no way to know the exactly central value expected for signal events because we would need to estimate the upper limit for the coupling constant $g_{Z'}$.

# %%
list_info = ['Eff_Bkg_index_00a.txt', 'Eff_Bkg_index_01a.txt', 'Eff_Bkg_index_02a.txt', 'Eff_Bkg_index_00b.txt', 'Eff_Bkg_index_01b.txt', 'Eff_Bkg_index_02b.txt']

EffSig_nBkg = [lambda arg=info:  np.loadtxt(info, usecols=(3,4), skiprows=1) for info in list_info]

for index in range(0, len(labelsamples)):
    for i in range(0,len(CosSun_Atm_list)):
        
        ExpectedBkg = 0
        if i % 3 == 0:
            ExpectedBkg = ExpectedBkgList[0]
        if i % 3 == 1:
            ExpectedBkg = ExpectedBkgList[1]
        if i % 3 == 2:
            ExpectedBkg = ExpectedBkgList[2]

        print('====================================================\n')
        print('Atmospheric Nuclear Model: '+ CosSun_Atm_list[i])
        AtmosphericSample = np.loadtxt(main_folder+CosSun_Atm_list[i])
        print('Sample: '+labelsamples[index]+'\n')
        print(f'Total Expected Number of Neutrinos Interactions: {round(ExpectedBkg)}\n')
        print(f'Number of Atmospheric Neutrinos Events Reconstructed: {AtmosphericSample.size}')
        print(f'Optimal Cosine Cuts => cos(theta_Sun) < {OptimalAngCuts[index][0]} and cos(theta_Sun) > {OptimalAngCuts[index][1]}. \n')
        EventsWithinOptAngCuts = AtmosphericSample[AtmosphericSample < OptimalAngCuts[index][0]].size +  AtmosphericSample[AtmosphericSample > OptimalAngCuts[index][1]].size
        print(f'Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: {EventsWithinOptAngCuts} \n')
        ExpectedBkgWithinOptAngCuts = ExpectedBkg*(EventsWithinOptAngCuts/AtmosphericSample.size)
        print(f'Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: {round(ExpectedBkgWithinOptAngCuts)} \n')
        print(f'Square root: {round(math.sqrt(ExpectedBkgWithinOptAngCuts))}')
        print(f'Uncertainty: {round(math.sqrt(ExpectedBkgWithinOptAngCuts)/ExpectedBkgWithinOptAngCuts,3)*100 }%')

        if (round(math.sqrt(ExpectedBkgWithinOptAngCuts)/ExpectedBkgWithinOptAngCuts,3)*100 >  LargerUnc):
            LargerUnc = round(math.sqrt(ExpectedBkgWithinOptAngCuts)/ExpectedBkgWithinOptAngCuts,3)*100
print(f'The Larger uncertainty found combining all nuclear models in all selection cuts is: {LargerUnc} %')
# Out:
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 22648
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10251
#
# Square root: 101
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 147146
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10719
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 108015
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10002
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116438
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10348
#
# Square root: 102
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 116454
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 10736
#
# Square root: 104
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p1_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -0.9 and cos(theta_Sun) > 0.9.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 115566
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9990
#
# Square root: 100
# Uncertainty: 1.0%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 17027
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7707
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 110294
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8034
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 81195
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7519
#
# Square root: 87
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86894
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7722
#
# Square root: 88
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 87291
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8047
#
# Square root: 90
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b1p5_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.85.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 86216
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 7453
#
# Square root: 86
# Uncertainty: 1.2%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 19025
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8611
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 123449
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8992
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 90843
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8412
#
# Square root: 92
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97252
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8643
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97707
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9008
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m05
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 96477
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8340
#
# Square root: 91
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 19025
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8611
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 123449
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8992
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 90843
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8412
#
# Square root: 92
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97252
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8643
#
# Square root: 93
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 97707
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 9008
#
# Square root: 95
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m10
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.832.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 96477
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 8340
#
# Square root: 91
# Uncertainty: 1.0999999999999999%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 11937
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5403
#
# Square root: 74
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 77336
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5633
#
# Square root: 75
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 56943
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5273
#
# Square root: 73
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 60883
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5411
#
# Square root: 74
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 61151
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5638
#
# Square root: 75
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m20
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.895.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 60560
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5235
#
# Square root: 72
# Uncertainty: 1.4000000000000001%
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 220573
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 13212
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5980
#
# Square root: 77
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1420286
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 85333
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 6216
#
# Square root: 79
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1037529
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 62923
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5827
#
# Square root: 76
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 99839
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1123411
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 67317
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5983
#
# Square root: 77
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 103459
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1122218
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 67588
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 6231
#
# Square root: 79
# Uncertainty: 1.3%
# ====================================================
#
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# Sample: b10_m40
#
# Total Expected Number of Neutrinos Interactions: 96075
#
# Number of Atmospheric Neutrinos Events Reconstructed: 1111390
# Optimal Cosine Cuts => cos(theta_Sun) < -1.1 and cos(theta_Sun) > 0.884.
#
# Number of Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 66805
#
# Number of Expected Atmospheric Neutrino Events Reconstructed inside the Angular Cuts: 5775
#
# Square root: 76
# Uncertainty: 1.3%
# The Larger uncertainty found combining all nuclear models in all selection cuts is: 1.4000000000000001 %

# %% [markdown]
# ### Let's fit the angular Neutrino distribution w.r.t Sun.

# %%
def fit_atmospherics(model):    
    # Create a histogram
    counts, bin_edges = np.histogram(model, bins=10, density=True)
    # Get the bin centers
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    # Fit a polynomial to the histogram data (e.g., a 3rd-degree polynomial)
    coefficients, cov = np.polyfit(bin_centers, counts, deg=2, cov= True)
    
    return coefficients, cov

# %%
results = []
for model in hist_numodel:
    results.append(fit_atmospherics(model))

# %%
import pandas as pd

df = pd.DataFrame()


for index in range(0, len(labelsamples)):
    print('====================================================\n')
    print('Sample: '+labelsamples[index]+'\n')
    print('====================================================\n')
    nms = []
    nevts= []
    for i in range(0,len(CosSun_Atm_list)):
        
        ExpectedBkg = 0
        if i % 3 == 0:
            ExpectedBkg = ExpectedBkgList[0]
        if i % 3 == 1:
            ExpectedBkg = ExpectedBkgList[1]
        if i % 3 == 2:
            ExpectedBkg = ExpectedBkgList[2]


        print('Atmospheric Nuclear Model: '+ CosSun_Atm_list[i])
        AtmosphericSample = np.loadtxt(main_folder+CosSun_Atm_list[i])
        
        EventsWithinOptAngCuts = AtmosphericSample[AtmosphericSample < OptimalAngCuts[index][0]].size +  AtmosphericSample[AtmosphericSample > OptimalAngCuts[index][1]].size
        ExpectedBkgWithinOptAngCuts = ExpectedBkg*(EventsWithinOptAngCuts/AtmosphericSample.size)
        ratioEvtsInsideOutside = EventsWithinOptAngCuts/AtmosphericSample.size
        nms.append(ratioEvtsInsideOutside)
        nevts.append(ExpectedBkgWithinOptAngCuts)
        print(f'RatioEvts Inside: {round(ratioEvtsInsideOutside,5)}')
        print(f'Events Inside Number: {round(ExpectedBkgWithinOptAngCuts,1)}')
    print(f'Std of the model: {round(np.std(nms),5)}')
    print(f'Std/Mean: {round(np.std(nms)/np.mean(nms),5)}')
    print(f'Std of the model number events: {round(np.std(nevts),5)}')
    print(f'Std/Mean: {round(np.std(nevts)/np.mean(nevts),5)}')
# Out:
# ====================================================
#
# Sample: b1p1_m05
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Events Inside Number: 10251.3
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Events Inside Number: 10718.7
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Events Inside Number: 10002.2
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Events Inside Number: 10348.0
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Events Inside Number: 10736.1
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# Events Inside Number: 9990.2
# Std of the model: 0.00046
# Std/Mean: 0.00446
# Std of the model number events: 301.2816
# Std/Mean: 0.02913
# ====================================================
#
# Sample: b1p1_m10
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Events Inside Number: 10251.3
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Events Inside Number: 10718.7
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Events Inside Number: 10002.2
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Events Inside Number: 10348.0
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Events Inside Number: 10736.1
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# Events Inside Number: 9990.2
# Std of the model: 0.00046
# Std/Mean: 0.00446
# Std of the model number events: 301.2816
# Std/Mean: 0.02913
# ====================================================
#
# Sample: b1p1_m20
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Events Inside Number: 10251.3
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Events Inside Number: 10718.7
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Events Inside Number: 10002.2
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Events Inside Number: 10348.0
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Events Inside Number: 10736.1
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# Events Inside Number: 9990.2
# Std of the model: 0.00046
# Std/Mean: 0.00446
# Std of the model number events: 301.2816
# Std/Mean: 0.02913
# ====================================================
#
# Sample: b1p1_m40
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Events Inside Number: 10251.3
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Events Inside Number: 10718.7
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Events Inside Number: 10002.2
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Events Inside Number: 10348.0
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Events Inside Number: 10736.1
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# Events Inside Number: 9990.2
# Std of the model: 0.00046
# Std/Mean: 0.00446
# Std of the model number events: 301.2816
# Std/Mean: 0.02913
# ====================================================
#
# Sample: b1p5_m05
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Events Inside Number: 7707.0
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Events Inside Number: 8034.2
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Events Inside Number: 7518.7
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Events Inside Number: 7722.4
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Events Inside Number: 8047.5
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# Events Inside Number: 7453.0
# Std of the model: 0.00034
# Std/Mean: 0.00437
# Std of the model number events: 228.59792
# Std/Mean: 0.02951
# ====================================================
#
# Sample: b1p5_m10
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Events Inside Number: 7707.0
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Events Inside Number: 8034.2
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Events Inside Number: 7518.7
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Events Inside Number: 7722.4
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Events Inside Number: 8047.5
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# Events Inside Number: 7453.0
# Std of the model: 0.00034
# Std/Mean: 0.00437
# Std of the model number events: 228.59792
# Std/Mean: 0.02951
# ====================================================
#
# Sample: b1p5_m20
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Events Inside Number: 7707.0
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Events Inside Number: 8034.2
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Events Inside Number: 7518.7
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Events Inside Number: 7722.4
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Events Inside Number: 8047.5
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# Events Inside Number: 7453.0
# Std of the model: 0.00034
# Std/Mean: 0.00437
# Std of the model number events: 228.59792
# Std/Mean: 0.02951
# ====================================================
#
# Sample: b1p5_m40
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Events Inside Number: 7707.0
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Events Inside Number: 8034.2
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Events Inside Number: 7518.7
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Events Inside Number: 7722.4
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Events Inside Number: 8047.5
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# Events Inside Number: 7453.0
# Std of the model: 0.00034
# Std/Mean: 0.00437
# Std of the model number events: 228.59792
# Std/Mean: 0.02951
# ====================================================
#
# Sample: b10_m05
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.08625
# Events Inside Number: 8611.4
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.08692
# Events Inside Number: 8992.5
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.08756
# Events Inside Number: 8412.1
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.08657
# Events Inside Number: 8642.9
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.08707
# Events Inside Number: 9007.7
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.08681
# Events Inside Number: 8340.0
# Std of the model: 0.00041
# Std/Mean: 0.00467
# Std of the model number events: 257.42171
# Std/Mean: 0.0297
# ====================================================
#
# Sample: b10_m10
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.08625
# Events Inside Number: 8611.4
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.08692
# Events Inside Number: 8992.5
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.08756
# Events Inside Number: 8412.1
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.08657
# Events Inside Number: 8642.9
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.08707
# Events Inside Number: 9007.7
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.08681
# Events Inside Number: 8340.0
# Std of the model: 0.00041
# Std/Mean: 0.00467
# Std of the model number events: 257.42171
# Std/Mean: 0.0297
# ====================================================
#
# Sample: b10_m20
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.05412
# Events Inside Number: 5403.1
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.05445
# Events Inside Number: 5633.4
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.05488
# Events Inside Number: 5272.9
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.05419
# Events Inside Number: 5410.8
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.05449
# Events Inside Number: 5637.6
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.05449
# Events Inside Number: 5235.2
# Std of the model: 0.00025
# Std/Mean: 0.00453
# Std of the model number events: 157.15102
# Std/Mean: 0.02893
# ====================================================
#
# Sample: b10_m40
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.0599
# Events Inside Number: 5980.2
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.06008
# Events Inside Number: 6216.0
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.06065
# Events Inside Number: 5826.7
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.05992
# Events Inside Number: 5982.6
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.06023
# Events Inside Number: 6231.0
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.06011
# Events Inside Number: 5775.0
# Std of the model: 0.00025
# Std/Mean: 0.00415
# Std of the model number events: 173.85178
# Std/Mean: 0.02897

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad
from scipy.integrate import trapz

# Assuming hist_numodel and LIST_NUCLEARMODELS are defined

fig, axes = plt.subplots(3, 2, figsize=(12, 10), dpi=150)
axes = axes.flatten()  # Flatten to iterate easily in a 3x2 grid layout

for id, model in enumerate(hist_numodel):
    # Access the current subplot
    ax = axes[id]
    
    # Create a polynomial function using the coefficients
    polynomial = np.poly1d(results[id][0])
    
    # Generate points to plot the polynomial
    x_values = np.linspace(-1, 1, 50)
    y_values = polynomial(x_values)

    # Calculate uncertainties and propagate them to the fit
    uncertainties = np.sqrt(np.diag(results[id][1]))
    y_fit_uncertainty = np.sqrt(
        (uncertainties[0] * x_values**2)**2 +
        (uncertainties[1] * x_values)**2 +
        (uncertainties[2])**2
    )

    # Integrate the polynomial function over the range of x
    #area_under_curve, _ = quad(polynomial, -1, 1)
    #print(f"Area under the curve for {LIST_NUCLEARMODELS[id]}: {area_under_curve}")
    # Calculate the area under the curve
    area = trapz(y_values + 2*y_fit_uncertainty, x_values)
    print(f"Area under the curve:for {LIST_NUCLEARMODELS[id]}: {area}")
    
    # Plot the histogram for the model
    ax.hist(hist_numodel[id], bins=10, density=True, alpha=0.6, color='g', histtype='step', 
            label='Reconstructed ' + LIST_NUCLEARMODELS[id])

    # Plot the fitted polynomial
    ax.plot(x_values, y_values, label='Fitted polynomial', color='red')

    # Plot the fit uncertainty as a shaded region
    ax.fill_between(x_values, y_values - y_fit_uncertainty, y_values + y_fit_uncertainty, 
                    color='red', alpha=0.3, label='Fit uncertainty')

    # Label axes and add a legend with the area under the curve
    ax.set_xlabel(r'cos($\theta_{Sun}$)')
    ax.set_ylabel('Density')
    ax.legend(title=rf'Area for y_fit+2$\sigma$: {round(area, 5)}', loc='lower center')

# Adjust layout and remove extra subplots if there are less than 6 models
for j in range(id + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.savefig('AngularStudiesPlots/AtmosphericNuclearModelFit_all.pdf', format='pdf', dpi=600)
plt.show()
# Out:
# Area under the curve:for hA_BR: 1.0055312087874715
# Area under the curve:for hA_LFG: 1.0060251828381612
# Area under the curve:for hA_ESF: 1.0061160053259763
# Area under the curve:for hN_BR: 1.008674173430839
# Area under the curve:for hN_LFG: 1.0046623211160024
# Area under the curve:for hN_ESF: 1.0096840556739533

# %%
import pandas as pd

df = pd.DataFrame()
nms = []

for index in range(0, len(labelsamples)):
    print('====================================================\n')
    print('Sample: '+labelsamples[index]+'\n')
    print('====================================================\n')
    
    for i in range(0,len(CosSun_Atm_list)):
        
        ExpectedBkg = 0
        if i % 3 == 0:
            ExpectedBkg = ExpectedBkgList[0]
        if i % 3 == 1:
            ExpectedBkg = ExpectedBkgList[1]
        if i % 3 == 2:
            ExpectedBkg = ExpectedBkgList[2]


        print('Atmospheric Nuclear Model: '+ CosSun_Atm_list[i])
        AtmosphericSample = np.loadtxt(main_folder+CosSun_Atm_list[i])
        
        EventsWithinOptAngCuts = AtmosphericSample[AtmosphericSample < OptimalAngCuts[index][0]].size +  AtmosphericSample[AtmosphericSample > OptimalAngCuts[index][1]].size
        ExpectedBkgWithinOptAngCuts = ExpectedBkg*(EventsWithinOptAngCuts/AtmosphericSample.size)
        ratioEvtsInsideOutside = EventsWithinOptAngCuts/AtmosphericSample.size
        nms.append(ratioEvtsInsideOutside)
        print(f'RatioEvts Inside: {round(ratioEvtsInsideOutside,5)}')
# Out:
# ====================================================
#
# Sample: b1p1_m05
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# ====================================================
#
# Sample: b1p1_m10
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# ====================================================
#
# Sample: b1p1_m20
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# ====================================================
#
# Sample: b1p1_m40
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.10268
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.1036
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.10411
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.10365
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.10377
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.10398
# ====================================================
#
# Sample: b1p5_m05
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# ====================================================
#
# Sample: b1p5_m10
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# ====================================================
#
# Sample: b1p5_m20
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# ====================================================
#
# Sample: b1p5_m40
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.07719
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.07766
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.07826
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.07735
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.07778
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.07757
# ====================================================
#
# Sample: b10_m05
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.08625
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.08692
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.08756
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.08657
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.08707
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.08681
# ====================================================
#
# Sample: b10_m10
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.08625
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.08692
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.08756
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.08657
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.08707
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.08681
# ====================================================
#
# Sample: b10_m20
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.05412
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.05445
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.05488
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.05419
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.05449
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.05449
# ====================================================
#
# Sample: b10_m40
#
# ====================================================
#
# Atmospheric Nuclear Model: hA_BR/CosSun_Atm_00a.txt
# RatioEvts Inside: 0.0599
# Atmospheric Nuclear Model: hA_LFG/CosSun_Atm_01a.txt
# RatioEvts Inside: 0.06008
# Atmospheric Nuclear Model: hA_ESF/CosSun_Atm_02a.txt
# RatioEvts Inside: 0.06065
# Atmospheric Nuclear Model: hN_BR/CosSun_Atm_00b.txt
# RatioEvts Inside: 0.05992
# Atmospheric Nuclear Model: hN_LFG/CosSun_Atm_01b.txt
# RatioEvts Inside: 0.06023
# Atmospheric Nuclear Model: hN_ESF/CosSun_Atm_02b.txt
# RatioEvts Inside: 0.06011

# %%
import pandas as pd

df = pd.DataFrame()
nms = []

for index in range(0, len(labelsamples)):
    print('====================================================\n')
    print('Sample: '+labelsamples[index]+'\n')
    print('====================================================\n')
    
    for i in range(0,len(CosSun_Atm_list)):
        
        ExpectedBkg = 0
        if i % 3 == 0:
            ExpectedBkg = ExpectedBkgList[0]
        if i % 3 == 1:
            ExpectedBkg = ExpectedBkgList[1]
        if i % 3 == 2:
            ExpectedBkg = ExpectedBkgList[2]


        print('Atmospheric Nuclear Model: '+ CosSun_Atm_list[i])
        AtmosphericSample = np.loadtxt(main_folder+CosSun_Atm_list[i])
        
        EventsWithinOptAngCuts = AtmosphericSample[AtmosphericSample < OptimalAngCuts[index][0]].size +  AtmosphericSample[AtmosphericSample > OptimalAngCuts[index][1]].size
        ExpectedBkgWithinOptAngCuts = ExpectedBkg*(EventsWithinOptAngCuts/AtmosphericSample.size)
        ratioEvtsInsideOutside = EventsWithinOptAngCuts/AtmosphericSample.size
        nms.append(ratioEvtsInsideOutside)
        print(f'RatioEvts Inside: {round(ratioEvtsInsideOutside,5)}')
# Out:
# ====================================================
#
# Sample: b1p1_m05
#
# ====================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 15
#      13 ExpectedBkg = 0
#      14 if i % 3 == 0:
# ---> 15     ExpectedBkg = ExpectedBkgList[0]
#      16 if i % 3 == 1:
#      17     ExpectedBkg = ExpectedBkgList[1]
#
# NameError: name 'ExpectedBkgList' is not defined
