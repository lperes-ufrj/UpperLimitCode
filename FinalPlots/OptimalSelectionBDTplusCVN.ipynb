# %%
import numpy as np
from array import *
import matplotlib.pyplot as plt
import math
import time

# %%
#Read CosSun Score for each lorentz factor and atmospheric neutrinos

CosSun_b1p1_m05 = np.loadtxt('CosSun_bdm_m05_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m05 = np.loadtxt('CosSun_bdm_m05_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m05 = np.loadtxt('CosSun_bdm_m05_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_b1p1_m10 = np.loadtxt('CosSun_bdm_m10_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m10 = np.loadtxt('CosSun_bdm_m10_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m10 = np.loadtxt('CosSun_bdm_m10_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_b1p1_m20 = np.loadtxt('CosSun_bdm_m20_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m20 = np.loadtxt('CosSun_bdm_m20_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m20 = np.loadtxt('CosSun_bdm_m20_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_b1p1_m40 = np.loadtxt('CosSun_bdm_m40_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b1p5_m40 = np.loadtxt('CosSun_bdm_m40_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_b10_m40 = np.loadtxt('CosSun_bdm_m40_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm = np.loadtxt('CosSun_Atm_hA_BR.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

# %%
#Read CosSun Score for each lorentz factor and atmospheric neutrinos after cuts

CosSun_Signal_b1p1_m05 = np.loadtxt('CosSunSignalAfterCuts_bdm_m05_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m05 = np.loadtxt('CosSunSignalAfterCuts_bdm_m05_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m05 = np.loadtxt('CosSunSignalAfterCuts_bdm_m05_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Signal_b1p1_m10 = np.loadtxt('CosSunSignalAfterCuts_bdm_m10_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m10 = np.loadtxt('CosSunSignalAfterCuts_bdm_m10_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m10 = np.loadtxt('CosSunSignalAfterCuts_bdm_m10_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Signal_b1p1_m20 = np.loadtxt('CosSunSignalAfterCuts_bdm_m20_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m20 = np.loadtxt('CosSunSignalAfterCuts_bdm_m20_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m20 = np.loadtxt('CosSunSignalAfterCuts_bdm_m20_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Signal_b1p1_m40 = np.loadtxt('CosSunSignalAfterCuts_bdm_m40_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b1p5_m40 = np.loadtxt('CosSunSignalAfterCuts_bdm_m40_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Signal_b10_m40 = np.loadtxt('CosSunSignalAfterCuts_bdm_m40_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)


CosSun_Atm_b1p1_m05 = np.loadtxt('CosSunAtmAfterCuts_bdm_m05_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m05 = np.loadtxt('CosSunAtmAfterCuts_bdm_m05_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m05 = np.loadtxt('CosSunAtmAfterCuts_bdm_m05_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm_b1p1_m10 = np.loadtxt('CosSunAtmAfterCuts_bdm_m10_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m10 = np.loadtxt('CosSunAtmAfterCuts_bdm_m10_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m10 = np.loadtxt('CosSunAtmAfterCuts_bdm_m10_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm_b1p1_m20 = np.loadtxt('CosSunAtmAfterCuts_bdm_m20_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m20 = np.loadtxt('CosSunAtmAfterCuts_bdm_m20_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m20 = np.loadtxt('CosSunAtmAfterCuts_bdm_m20_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

CosSun_Atm_b1p1_m40 = np.loadtxt('CosSunAtmAfterCuts_bdm_m40_b1p1_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b1p5_m40 = np.loadtxt('CosSunAtmAfterCuts_bdm_m40_b1p5_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)
CosSun_Atm_b10_m40 = np.loadtxt('CosSunAtmAfterCuts_bdm_m40_b10_00a.txt', delimiter=' ', skiprows=1,  dtype=np.float32)

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=12)
bestCutRight = 0.179
bestCutLeft = -0.051

plt.figure(dpi=100)
plt.xlabel(r'$\cos (\theta_{Sun})$', fontsize = 18)
plt.yscale('log')
plt.ylim([1,1e6])
h1, x1, _ = plt.hist(CosSun_Atm_b1p1_m10, bins= 30, density=False, label=r'Atm-$\nu$ w/ CVN+BDT Selection', histtype='step', lw =1, color = 'blue', ls='--')
h2, x2, _ = plt.hist(CosSun_Signal_b1p1_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$ w/ CVN+BDT Selection', histtype='step', color='darkorange',lw =1, ls='--')
h3, x3, _ = plt.hist(CosSun_Atm, bins= 30, density=False, label=r'Atm-$\nu$', histtype='step', lw =1, color = 'blue', ls= '-')
h4, x4, _ = plt.hist(CosSun_b1p1_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$', histtype='step', lw =1,color = 'darkorange')
#plt.xlabel(r'$\cos(\theta_{\Sun})$')
plt.vlines(bestCutRight, 0, 3*1e4, colors='darkolivegreen', linestyles='solid',lw=2)
plt.vlines(bestCutLeft, 0, 3*1e4, colors='darkolivegreen', linestyles='solid',lw=2)
plt.plot(bestCutLeft-0.07, 1e3, marker=r'$\leftarrow$', markersize=20,markerfacecolor='#FFA500',markeredgecolor="darkolivegreen")
plt.plot(bestCutRight+0.06, 1e3, marker=r'$\rightarrow$', markersize=20,markerfacecolor='#FFA500',markeredgecolor="darkolivegreen")
plt.ylabel('Number of Events Reconstructed')
plt.legend(title = r'$\gamma = 1.1,$ hA+BR',loc='upper center',ncol=2, fontsize=10)
plt.savefig('b1p1_cvnbdt_selection'+str(time.strftime("%Y%m%d"))+'.pdf', format='pdf', dpi=600)
plt.show()

# %%
CosSun_Atm_b1p1_m10.size/CosSun_Atm.size
# Out:
# 0.03553034836697314

# %%
CosSun_Signal_b1p1_m10.size/CosSun_b1p1_m10.size
# Out:
# 0.6811302783363319

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=12)

plt.figure(dpi=100)
plt.xlabel(r'$\cos (\theta_{Sun})$', fontsize = 18)
plt.yscale('log')
plt.ylim([1,1e6])
h1, x1, _ = plt.hist(CosSun_Atm_b1p5_m10, bins= 30, density=False, label=r'Atm-$\nu$ w/ CVN+BDT Selection', histtype='step',lw =1, color = 'blue', ls='--')
h2, x2, _ = plt.hist(CosSun_Signal_b1p5_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$ w/ CVN+BDT Selection', histtype='step', color='darkorange',lw =1, ls='--')
h3, x3, _ = plt.hist(CosSun_Atm, bins= 30, density=False, label=r'Atm-$\nu$', histtype='step', lw =1, color = 'blue', ls= '-')
h4, x4, _ = plt.hist(CosSun_b1p5_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$', histtype='step', lw =1,color = 'darkorange')
#plt.xlabel(r'$\cos(\theta_{\Sun})$')
plt.ylabel('Number of Events Reconstructed')
plt.legend(title = r'$\gamma = 1.5,$ hA+BR',loc='upper center',ncol=2, fontsize=10)
plt.savefig('b1p5_cvnbdt_selection'+str(time.strftime("%Y%m%d"))+'.pdf', format='pdf', dpi=600)
plt.show()

# %%
plt.rc('text', usetex=True)
plt.rc('font', size=12)
bestCutRight=0.872
plt.figure(dpi=100)
plt.xlabel(r'$\cos (\theta_{Sun})$', fontsize = 18)
plt.yscale('log')
plt.ylim([1,1e8])
h1, x1, _ = plt.hist(CosSun_Atm_b10_m10, bins= 30, density=False, label=r'Atm-$\nu$ w/ CVN+BDT Selection', histtype='step',lw =1, color = 'blue', ls='--')
h2, x2, _ = plt.hist(CosSun_Signal_b10_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$ w/ CVN+BDT Selection', histtype='step', color='darkorange',lw =1, ls='--')
h3, x3, _ = plt.hist(CosSun_Atm, bins= 30, density=False, label=r'Atm-$\nu$', histtype='step', lw =1, color = 'blue', ls= '-')
h4, x4, _ = plt.hist(CosSun_b10_m10, bins= 30, density=False, label=r'$m_\chi=10 \textrm{ GeV}$', histtype='step', lw =1,color = 'darkorange')
#plt.xlabel(r'$\cos(\theta_{\Sun})$')
h = max(h1.max(),h2.max(),h3.max(), h4.max())
plt.vlines(bestCutRight, 0, 1e6, colors='darkolivegreen', linestyles='solid',lw=2)
plt.plot(bestCutRight+0.06, h.max()*2, marker=r'$\rightarrow$', markersize=20,markerfacecolor='darkolivegreen',markeredgecolor="darkolivegreen")
plt.ylabel('Number of Events Reconstructed')
plt.legend(title = r'$\gamma = 10,$ hA+BR',loc='upper center',ncol=2, fontsize=10)
plt.savefig('b10_cvnbdt_selection'+str(time.strftime("%Y%m%d"))+'.pdf', format='pdf', dpi=600)
plt.show()
